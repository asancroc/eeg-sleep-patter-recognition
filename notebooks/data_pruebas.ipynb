# %%
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf

import glob
import polars as pl
from sklearn.decomposition import PCA

sys.path.append(os.path.join(os.path.dirname(os.path.realpath('__file__')), '../'))
from exp_utils import (
    d_users_split, normalize_df_columns_0_1
)

# %%
def num_labels(df):
    d_labels = {'W': 0, '1': 1, '2': 2, '3': 3, '4': 4, 'e': 5, 'R': 6, '?': 7}

    df['label'] = df['label'].map(d_labels)

    return df


def gather_signals_by_class(df_raw, num_signals=20):
    """
    Organize data by class, collecting sets of `num_signals` signals per class.
    """
    grouped = df_raw.groupby('label')
    grouped_data = []
    
    for _, group in grouped:
        for i in range(0, len(group), num_signals):
            subset = group.iloc[i:i+num_signals]
            if len(subset) == num_signals:
                grouped_data.append(subset)
                
    return pd.concat(grouped_data)

def get_dataset(paths_csv: list = None, shuffle: bool = False, batch_size: int = 32, 
                over_samp: bool = False, return_data: bool = False, num_signals: int = 20):
    # Load CSV data
    df_raw = pd.DataFrame()
    
    # Load and concatenate CSV files
    for path in paths_csv:
        temp_df = pd.read_csv(path, delimiter=';', header=0)
        df_raw = pd.concat([df_raw, temp_df], ignore_index=True)    
    
    df_raw = num_labels(df=df_raw)
    
    if over_samp:
        # Implement over_sampling logic here
        pass

    # Organize data by class, collecting sets of num_signals signals per class
    data_processed = gather_signals_by_class(df_raw, num_signals=num_signals)
    
    if shuffle:
        # Shuffling here would disrupt the grouping, consider shuffling within groups if necessary
        pass

    # Extracting sensor data and labels
    sensor_data = data_processed[['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6', 'sensor_7']].values
    labels = data_processed['label'].values[::num_signals]  # Assuming the same label for each group of 20 signals

    # Reshape data to have 'num_signals' signals per item
    sensor_data_reshaped = sensor_data.reshape(-1, num_signals, sensor_data.shape[1])
    labels_one_hot = tf.keras.utils.to_categorical(labels)

    # Create TensorFlow Dataset
    dataset = tf.data.Dataset.from_tensor_slices((sensor_data_reshaped, labels_one_hot))

    if batch_size is not None:
        dataset = dataset.batch(batch_size)

    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)

    if return_data:
        return dataset, labels_one_hot
    else:
        return dataset

# %%
glob.glob('..\zhang-wamsley-2019\data\CSV\*.csv')
# Out:
# ['..\\zhang-wamsley-2019\\data\\CSV\\subject010_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO1-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject010_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO7-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject026_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO1-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO10-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO4-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO6-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO7-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject030_SO9-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject042_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject083_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject083_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject083_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject083_SO1-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject083_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject088_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject107_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject126_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO3-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject181_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO1-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO2-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO5-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO6-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject183_SO9-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_SO5-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject185_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO4-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO5-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO7-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject228_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO3-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO7-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject245_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject249_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject266_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject266_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject266_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject266_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject266_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject266_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO2-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject309_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_SO2-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_SO4-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_SO5-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject337_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject347_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject374_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject384_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject384_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject384_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject384_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject384_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject384_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject388_Morning-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject388_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject388_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject388_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject388_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject388_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO2-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO6-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject411_SO9-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO10-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO7-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject422_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_NREM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject452_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_REM-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO6-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject455_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO8-0.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject512_SO9-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_Morning-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_NREM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_REM-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO1-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO10-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO2-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO3-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO4-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO5-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO6-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO7-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO8-1.csv',
#  '..\\zhang-wamsley-2019\\data\\CSV\\subject535_SO9-1.csv']

# %%
tf_dataset = get_dataset(paths_csv=glob.glob('../sleep-cassette-csv/*.csv'), shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alvar\anaconda3\envs\python-ia-master\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\Users\alvar\anaconda3\envs\python-ia-master\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\alvar\anaconda3\envs\python-ia-master\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tf_dataset = get_dataset(paths_csv=glob.glob('sleep-cassette-csv/*.csv'), shuffle=True)
#
# Cell In[2], line 34, in get_dataset(paths_csv, shuffle, batch_size, over_samp, return_data, num_signals)
#      31     temp_df = pd.read_csv(path, delimiter=';', header=0)
#      32     df_raw = pd.concat([df_raw, temp_df], ignore_index=True)
# ---> 34 df_raw = num_labels(df=df_raw)
#      36 if over_samp:
#      37     # Implement over_sampling logic here
#      38     pass
#
# Cell In[2], line 4, in num_labels(df)
#       1 def num_labels(df):
#       2     d_labels = {'W': 0, '1': 1, '2': 2, '3': 3, '4': 4, 'e': 5, 'R': 6, '?': 7}
# ----> 4     df['label'] = df['label'].map(d_labels)
#       6     return df
#
# File c:\Users\alvar\anaconda3\envs\python-ia-master\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File c:\Users\alvar\anaconda3\envs\python-ia-master\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'label'

# %%
tf_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 20, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, 8), dtype=tf.float32, name=None))>

# %%
df_raw = pd.read_csv('zhang-wamsley-2019/data/CSV/26-EEG.csv', delimiter=';', header=0)
df_raw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_raw = pd.read_csv('zhang-wamsley-2019/data/CSV/26-EEG.csv', delimiter=';', header=0)
#       2 df_raw
#
# NameError: name 'pd' is not defined

# %%
num_signals = 20
grouped = df_raw.groupby('label')
grouped_data = []

for _, group in grouped:
    for i in range(0, len(group), num_signals):
        subset = group.iloc[i:i+num_signals]
        if len(subset) == num_signals:
            grouped_data.append(subset)

# %%
df_agr = pd.concat(grouped_data)
df_agr
# Out:
#         sensor_1  sensor_2   sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  \
# 10829   9.947556 -1.916410   5.140684     154.0     1.298    13.191     951.0
# 10830  -3.767111  1.077021   1.759136     135.0     1.338    13.172     939.0
# 10831   2.742222  0.336117  -0.857314     125.0     1.332    13.212     962.0
# 10832   6.363556 -1.808889  -3.218730     160.0     1.346    13.164     958.0
# 10833   0.557333 -0.558388   1.825255     144.0     1.420    13.141     945.0
# ...          ...       ...        ...       ...       ...       ...       ...
# 78568   3.879111 -0.823126 -34.153284     150.0     1.398    13.136     962.0
# 78569 -16.284444 -2.771160  13.131717     130.0     3.682    13.117     955.0
# 78570  23.981333  5.258608   7.634339     153.0    -0.946    13.196     980.0
# 78571  11.715556 -1.105934   5.310706     121.0     0.740    13.245     989.0
# 78572  -3.892444 -7.676484  14.473001     113.0     0.994    13.189     957.0
#
#       label  user_id  user_night   sex  patient_age
# 10829     1       70           2  Male           89
# 10830     1       70           2  Male           89
# 10831     1       70           2  Male           89
# 10832     1       70           2  Male           89
# 10833     1       70           2  Male           89
# ...     ...      ...         ...   ...          ...
# 78568     W       70           2  Male           89
# 78569     W       70           2  Male           89
# 78570     W       70           2  Male           89
# 78571     W       70           2  Male           89
# 78572     W       70           2  Male           89
#
# [78540 rows x 12 columns]

# %%
sensor_data = df_agr[['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6', 'sensor_7']].values
labels = df_agr['label'].values[::num_signals]  # Assuming the same label for each group of 20 signals

# %%
len(labels)
# Out:
# 3927

# %%
sensor_data_reshaped = sensor_data.reshape(-1, num_signals, sensor_data.shape[1])
# labels_one_hot = tf.keras.utils.to_categorical(labels)

# %%
len(sensor_data_reshaped[1])
# Out:
# 20

# %%
data_raw = pd.DataFrame()
    
# Load and concatenate CSV files
for path in glob.glob('sleep-cassette-csv/*.csv'):
    temp_df = pd.read_csv(path, delimiter=';', header=0)
    data_raw = pd.concat([data_raw, temp_df], ignore_index=True)

# %%
data_raw
# Out:
#           sensor_1  sensor_2    sensor_3  sensor_4  sensor_5   sensor_6  \
# 0         1.781040  1.059883   -9.367766    -627.0     4.024  37.506115
# 1         3.469407  1.734300  -15.902869     619.0     3.982  37.488241
# 2       -13.997751  0.857656   36.609463    -520.0     4.114  37.507996
# 3        -3.853297  1.313158  -24.589011    -403.0     4.154  37.504233
# 4        34.658359  6.828264    6.485287     475.0     4.060  37.504233
# ...            ...       ...         ...       ...       ...        ...
# 6170554   0.207111  2.643062 -130.244115      51.0     3.198  14.100710
# 6170555  -0.831111  1.885011   -5.584733      30.0     3.062  14.045777
# 6170556  -3.521778  1.148808   58.984276      55.0     3.080  14.116732
# 6170557  -8.376000 -5.030545   13.712701      53.0     3.050  14.110323
# 6170558   6.928889  5.075856    4.173160      41.0     3.024  14.136416
#
#          sensor_7 label  user_id  user_night     sex  patient_age
# 0           977.0     W        0           2  Female           33
# 1           979.0     W        0           2  Female           33
# 2           997.0     W        0           2  Female           33
# 3          1015.0     W        0           2  Female           33
# 4          1016.0     W        0           2  Female           33
# ...           ...   ...      ...         ...     ...          ...
# 6170554     888.0     W       82           2  Female           56
# 6170555     820.0     W       82           2  Female           56
# 6170556     875.0     W       82           2  Female           56
# 6170557     858.0     W       82           2  Female           56
# 6170558     880.0     W       82           2  Female           56
#
# [6170559 rows x 12 columns]

# %%
data_raw = num_labels(data_raw)
data_raw
# Out:
#           sensor_1  sensor_2    sensor_3  sensor_4  sensor_5   sensor_6  \
# 0         1.781040  1.059883   -9.367766    -627.0     4.024  37.506115
# 1         3.469407  1.734300  -15.902869     619.0     3.982  37.488241
# 2       -13.997751  0.857656   36.609463    -520.0     4.114  37.507996
# 3        -3.853297  1.313158  -24.589011    -403.0     4.154  37.504233
# 4        34.658359  6.828264    6.485287     475.0     4.060  37.504233
# ...            ...       ...         ...       ...       ...        ...
# 6170554   0.207111  2.643062 -130.244115      51.0     3.198  14.100710
# 6170555  -0.831111  1.885011   -5.584733      30.0     3.062  14.045777
# 6170556  -3.521778  1.148808   58.984276      55.0     3.080  14.116732
# 6170557  -8.376000 -5.030545   13.712701      53.0     3.050  14.110323
# 6170558   6.928889  5.075856    4.173160      41.0     3.024  14.136416
#
#          sensor_7  label  user_id  user_night     sex  patient_age
# 0           977.0      0        0           2  Female           33
# 1           979.0      0        0           2  Female           33
# 2           997.0      0        0           2  Female           33
# 3          1015.0      0        0           2  Female           33
# 4          1016.0      0        0           2  Female           33
# ...           ...    ...      ...         ...     ...          ...
# 6170554     888.0      0       82           2  Female           56
# 6170555     820.0      0       82           2  Female           56
# 6170556     875.0      0       82           2  Female           56
# 6170557     858.0      0       82           2  Female           56
# 6170558     880.0      0       82           2  Female           56
#
# [6170559 rows x 12 columns]

# %%
data_raw['label'].value_counts()
# Out:
# 0    4229754
# 2     994814
# 6     399804
# 1     317965
# 3     132318
# 4      65515
# 7      28066
# 5       2323
# Name: label, dtype: int64
